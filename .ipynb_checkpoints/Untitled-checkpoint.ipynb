# %%
import pandas as pd

# %%
df = pd.read_csv('proxy_feature_df_stable_13_June.tsv', sep='\t')

# %%
df
# Out:
#     realMicRNA realMicRNAName    chr   startPos     endPos  \
# 0         Null           Null  chr16   69933102   69933125
# 1         Null           Null  chr17   17813897   17813916
# 2         Null           Null   chr7  130496161  130496184
# 3         Null           Null   chr7    1022989    1023012
# 4         Null           Null   chr5   88666863   88666887
# ..         ...            ...    ...        ...        ...
# 873       Null           Null   chr4   32728718   32728734
# 874       Null           Null   chr8  143915986  143916008
# 875       Null           Null   chr9  104928094  104928109
# 876       Null           Null   chr1  228288280  228288303
# 877       Null           Null  chr15   43531393   43531420
#
#                                            clusterName             clusterSeq  \
# 0    mapped_mirna_SRR333680:miRCluster_1868_24:chr1...   CAGTGGTTTTACCCTATGGT
# 1    mapped_mirna_ERR973611:miRCluster_4323_20:chr1...     GCATTGCTGTTGCATTGC
# ...

# %%
cols = list(pd.read_csv("/home/jfernand/gtex-smallrna-jcfc/generate_pileups/pileups_greater_than_one.unaligned.counts.tsv", 
                        nrows =1, sep='\t'))
pileup_counts = pd.read_csv('/home/jfernand/gtex-smallrna-jcfc/generate_pileups/pileups_greater_than_one.unaligned.counts.tsv', 
                      sep='\t', usecols =[i for i in cols if i != 'Unnamed: 0'])

# %%
pileup_counts
# Out:
#         contig  loose_count  majority_start  majority_end  strict_count
# 0         chr1            1           24894         24909             1
# 1         chr1            4           32557         32578             4
# 2         chr1            7           34463         34473             1
# 3         chr1            7           34462         34474             3
# 4         chr1            7           34463         34474             3
# ...        ...          ...             ...           ...           ...
# 2046731   chrY            1        56872320      56872330             1
# 2046732   chrY            1        56874711      56874725             1
# 2046733   chrY            2        56874711      56874730             2
# 2046734   chrY           34        56882779      56882794            34
# 2046735   chrY            2        56883492      56883507             2
#
# [2046736 rows x 5 columns]
