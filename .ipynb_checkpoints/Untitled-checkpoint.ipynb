# %% [markdown]
# # Make a reasonable train test split
# We want to hold out certain annotations from the test set to see how the model would generalize to unannotated miRNAs

# %%
import pandas as pd
import numpy
import re

# %% [markdown]
# I think just chromosomes 1, 7, and 14 would be good. For example.

# %%
df = pd.read_csv('SVM_training/all_tissues_mapped_dataset_15_refined_miRGeneDB_total_features_updated.csv')

# %%
df['chrom'] = [re.search('(?<=chr)[^:]*', cn).group(0) for cn in df['clusterName']]

# %%
df[df['chrom'].isin(['1', '8', '14'])]
# Out:
#        realMicRNA   realMicRNAName  \
# 0               1  hsa-miR-200b-5p
# 1               1  hsa-miR-200b-3p
# 2               1  hsa-miR-200a-3p
# 3               1      hsa-miR-429
# 4               1   hsa-miR-34a-5p
# ...           ...              ...
# 23970          -1             Null
# 23971          -1             Null
# 24063          -1             Null
# 24064          -1             Null
# 24065          -1             Null
#
#                                              clusterName  seqCount  \
# 0      mapped_mirna_ERR038410:miRCluster_1_22:chr1:11...         3
# 1      mapped_mirna_ERR038410:miRCluster_2_24:chr1:11...        20
# 2      mapped_mirna_ERR038410:miRCluster_3_23:chr1:11...        15
# 3      mapped_mirna_ERR038410:miRCluster_4_22:chr1:11...         3
# 4      mapped_mirna_ERR038410:miRCluster_31_23:chr1:9...        10
# ...                                                  ...       ...
# ...

# %% [markdown]
# Get a list of annotations. Split that list say 90-10. Filter the data frame to only the 90% annotations, and split that. Now we have some seen annotations in the test set. Then add back in the initial 10% of annotations that were unseen.
